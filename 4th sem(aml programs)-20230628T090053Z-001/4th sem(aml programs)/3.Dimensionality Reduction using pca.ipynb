# %%
# !pip install seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Collecting seaborn
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Requirement already satisfied: pandas>=0.25 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/nm21ai008/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
from sklearn.datasets import load_breast_cancercancer.isnull().sum()

# %%
cancer=load_breast_cancer()

# %%
df=pd.DataFrame(cancer['data'],columns=cancer['feature_names'])

# %%
df.head()
       ...,
       [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
        -1.10454895, -0.31840916],
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry
# 0           0.27760          0.3001              0.14710         0.2419  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter
# 0                 0.07871  ...         25.38          17.33           184.60  \
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity
# 0      2019.0            0.1622             0.6656           0.7119  \
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# ## PCA Visualization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(df)
scaled_data=scaler.transform(df)
scaled_data
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
scaled_data=pd.DataFrame(scaled_data)
scaled_data.head()
# Out:
#          0         1         2         3         4         5         6
# 0  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874  \
# 1  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
# 2  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926  1.363478
# 3 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909  1.915897
# 4  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340  1.371011
#
#          7         8         9   ...        20        21        22        23
# 0  2.532475  2.217515  2.255747  ...  1.886690 -1.359293  2.303601  2.001237  \
# 1  0.548144  0.001392 -0.868652  ...  1.805927 -0.369203  1.535126  1.890489
# 2  2.037231  0.939685 -0.398008  ...  1.511870 -0.023974  1.347475  1.456285
# 3  1.451707  2.867383  4.910919  ... -0.281464  0.133984 -0.249939 -0.550021
# 4  1.428493 -0.009560 -0.562450  ...  1.298575 -1.466770  1.338539  1.220724
#
#          24        25        26        27        28        29
# 0  1.307686  2.616665  2.109526  2.296076  2.750622  1.937015
# 1 -0.375612 -0.430444 -0.146749  1.087084 -0.243890  0.281190
# 2  0.527407  1.082932  0.854974  1.955000  1.152255  0.201391
# 3  3.394275  3.893397  1.989588  2.175786  6.046041  4.935010
# 4  0.220556 -0.313395  0.613179  0.729259 -0.868353 -0.397100
#
# [5 rows x 30 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit(scaled_data)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(scaled_data)
scaled_data.shape
# Out:
# (569, 30)
